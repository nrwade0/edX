# %%
print("Hello World!")
# Out:
# Hello World!

# %%
366*24*60*60
# Out:
# 31622400

# %%
_/1e6
# Out:
# 31.6224

# %%
x = 4+3
print(x)
# Out:
# 7

# %%
x = 10
print(x)
# Out:
# 10

# %% [markdown]
# # HEADING 1
# ## HEADING 2
#
# here is some markdown text
#
# * one fish, two fish
# * red fish, blue fish
#
# **bold two asterisks**
#
# *italics one asterisk*
#
# $ x \times y = xy $
#
# $\int_0^\infty x^{-\alpha}dx $

# %%
from matplotlib.pyplot import plot

plot([0,1,0,1])

# %% [markdown]
# This is a plot using matplotlib of a vector.
